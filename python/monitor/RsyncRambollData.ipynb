# %% [markdown]
# # Sync data from Ramboll Indoor Sensors

# %%
# %pylab inline
from glob import glob
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
! rsync -avzhe ssh pi@206.193.55.60:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Audubon
! rsync -avzhe ssh pi@206.193.55.61:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Browne
! rsync -avzhe ssh pi@206.193.55.62:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Balboa
# ! rsync -avzhe ssh pi@206.193.55.63:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Lidgerwood
! rsync -avzhe ssh pi@206.193.55.64:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Regal
! rsync -avzhe ssh pi@206.193.55.65:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Stevens
! rsync -avzhe ssh pi@206.193.55.66:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Jefferson
! rsync -avzhe ssh pi@206.193.55.67:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Adams
! rsync -avzhe ssh pi@206.193.55.68:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Grant
#! rsync -avzhe ssh pi@206.193.55.69:/home/pi/SpokaneSchools/Data/Good_Data/ /Users/vonw/data/urbanova/ramboll/Sheridan
# Out:
# receiving file list ... done
#
# sent 16 bytes  received 552 bytes  227.20 bytes/sec
# total size is 3.23M  speedup is 5691.19
# receiving file list ... done
#
# sent 16 bytes  received 527 bytes  362.00 bytes/sec
# total size is 3.38M  speedup is 6229.03
# receiving file list ... done
# WSU_LAR_Indoor_Air_Quality_Node_6_20190915_000048.json
#
# sent 530 bytes  received 2.19K bytes  1.09K bytes/sec
# total size is 3.43M  speedup is 1260.36
# receiving file list ... done
#
# sent 16 bytes  received 580 bytes  397.33 bytes/sec
# total size is 3.36M  speedup is 5636.93
# receiving file list ... done
#
# sent 16 bytes  received 619 bytes  423.33 bytes/sec
# total size is 3.22M  speedup is 5066.04
# receiving file list ... done
#
# sent 16 bytes  received 477 bytes  197.20 bytes/sec
# total size is 3.19M  speedup is 6474.82
# receiving file list ... done
#
# sent 16 bytes  received 478 bytes  329.33 bytes/sec
# total size is 3.19M  speedup is 6465.55
# receiving file list ... done
#
# ...

# %%
adams = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Adams/WSU_LAR_Indoor_Air_Quality_Node_9_201909*.json')
files.sort()
for file in files:
    adams = pd.concat([adams, pd.read_json(file)], sort=False)
adams.index = adams.Datetime

audubon = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Audubon/WSU_LAR_Indoor_Air_Quality_Node_11_201909*.json')
files.sort()
for file in files:
    audubon = pd.concat([audubon, pd.read_json(file)], sort=False)
audubon.index = audubon.Datetime

balboa = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Balboa/WSU_LAR_Indoor_Air_Quality_Node_6_201909*.json')
files.sort()
for file in files:
    balboa = pd.concat([balboa, pd.read_json(file)], sort=False)
balboa.index = balboa.Datetime

browne = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Browne/WSU_LAR_Indoor_Air_Quality_Node_5_201909*.json')
files.sort()
for file in files:
    browne = pd.concat([browne, pd.read_json(file)], sort=False)
browne.index = browne.Datetime

grant = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Grant/WSU_LAR_Indoor_Air_Quality_Node_4_201909*.json')
files.sort()
for file in files:
    grant = pd.concat([grant, pd.read_json(file)], sort=False)
grant.index = grant.Datetime

jefferson = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Jefferson/WSU_LAR_Indoor_Air_Quality_Node_8_201909*.json')
files.sort()
for file in files:
    jefferson = pd.concat([jefferson, pd.read_json(file)], sort=False)
jefferson.index = jefferson.Datetime

#lidgerwood = pd.DataFrame({})
#files   = glob('/Users/vonw/data/urbanova/ramboll/Lidgerwood/WSU_LAR_Indoor_Air_Quality_Node_3_201909*.json')
#files.sort()
#for file in files:
#    lidgerwood = pd.concat([lidgerwood, pd.read_json(file)], sort=False)
#lidgerwood.index = lidgerwood.Datetime

regal = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Regal/WSU_LAR_Indoor_Air_Quality_Node_10_201909*.json')
files.sort()
for file in files:
    regal = pd.concat([regal, pd.read_json(file)], sort=False)
regal.index = regal.Datetime

#sheridan = pd.DataFrame({})
#files   = glob('/Users/vonw/data/urbanova/ramboll/Sheridan/WSU_LAR_Indoor_Air_Quality_Node_1_201909*.json')
#files.sort()
#for file in files:
#    sheridan = pd.concat([sheridan, pd.read_json(file)], sort=False)
#sheridan.index = sheridan.Datetime

stevens = pd.DataFrame({})
files   = glob('/Users/vonw/data/urbanova/ramboll/Stevens/WSU_LAR_Indoor_Air_Quality_Node_2_201909*.json')
files.sort()
for file in files:
    stevens = pd.concat([stevens, pd.read_json(file)], sort=False)
stevens.index = stevens.Datetime

# %%
figure(figsize=(12,8))
adams.Temp.plot()
audubon.Temp.plot()
balboa.Temp.plot()
browne.Temp.plot()
grant.Temp.plot()
jefferson.Temp.plot()
regal.Temp.plot()
stevens.Temp.plot()
xlabel('Time (local)')
ylabel('Temperature (C)')
legend(['Adams',
        'Audubon',
        'Balboa',
        'Browne',
        'Grant',
        'Jefferson',
        'Regal',
        'Stevens'])

# %%
figure(figsize=(12,8))
adams.P.plot()
audubon.P.plot()
balboa.P.plot()
browne.P.plot()
grant.P.plot()
jefferson.P.plot()
regal.P.plot()
stevens.P.plot()
xlabel('Time (local)')
ylabel('Pressure (mb)')
legend(['Adams',
        'Audubon',
        'Balboa',
        'Browne',
        'Grant',
        'Jefferson',
        'Regal',
        'Stevens'])

# %%
figure(figsize=(12,8))
adams.PM2_5_env.plot()
audubon.PM2_5_env.plot()
balboa.PM2_5_env.plot()
browne.PM2_5_env.plot()
grant.PM2_5_env.plot()
jefferson.PM2_5_env.plot()
regal.PM2_5_env.plot()
stevens.PM2_5_env.plot()
xlabel('Time (local)')
ylabel('PM 2.5 (ug m-3)')
legend(['Adams',
        'Audubon',
        'Balboa',
        'Browne',
        'Grant',
        'Jefferson',
        'Regal',
        'Stevens'])

# %%
figure(figsize=(12,8))
adams.PM_0_5.plot()
audubon.PM_0_5.plot()
balboa.PM_0_5.plot()
browne.PM_0_5.plot()
grant.PM_0_5.plot()
jefferson.PM_0_5.plot()
regal.PM_0_5.plot()
stevens.PM_0_5.plot()
xlabel('Time (local)')
ylabel('PM 0.5 (ug m-3)')
legend(['Adams',
        'Audubon',
        'Balboa',
        'Browne',
        'Grant',
        'Jefferson',
        'Regal',
        'Stevens'])
